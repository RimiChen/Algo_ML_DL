# %% [markdown]
# ### Quick Sort

# %% [markdown]
# Custom Implementation

# %%
### QuickSort algorithm implemenetation
def quicksort(arr):
  ###  Base case: if the array has 1 or 0 elements, it's already sorted
  if len(arr) <= 1:
    return arr
  else:
    ### Select the pivot (choose the middle element)
    pivot = arr[len(arr) // 2]
    ### Elements smaller than the pivot
    left = [x for x in arr if x < pivot]
    ### Elements equal to the pivot
    middle = [x for x in arr if x == pivot]
    ### Elements greater than the pivot
    right = [x for x in arr if x > pivot]

    ### Recursively apply quicksort to left and right, and then combine
    return quicksort(left) + middle + quicksort(right)

arr = [3, 6, 8, 10, 1, 2, 1]
sorted_arr = quicksort(arr)
print("Sorted array", sorted_arr)
# Out:
# Sorted array [1, 1, 2, 3, 6, 8, 10]

# %% [markdown]
# Calling Quicksort-like function from a library

# %%
### the built-in sorting method, Python's sorted() function (uses TimSort)

arr = [3, 6, 8, 10, 1, 2, 1]
sorted_arr = sorted(arr)
print("Sorted array using built-in sorted():", sorted_arr)
# Out:
# Sorted array using built-in sorted(): [1, 1, 2, 3, 6, 8, 10]
